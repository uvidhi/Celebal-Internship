# %%
CATALOG = "retail_medallion_ws"
SCHEMA = "default"

RAW_VOLUME_ = f"/Volumes/{CATALOG}/{SCHEMA}/retail_raw"

CRM_PATH = f"{RAW_VOLUME_}/source_crm"
ERP_PATH = f"{RAW_VOLUME_}/source_erp"

print("Catalog:", CATALOG)
print("Schema:", SCHEMA)
print("CRM path:", CRM_PATH)
print("ERP path:", ERP_PATH)
# Out:
# Catalog: retail_medallion_ws
# Schema: default
# CRM path: /Volumes/retail_medallion_ws/default/retail_raw/source_crm
# ERP path: /Volumes/retail_medallion_ws/default/retail_raw/source_erp

# %%
display(dbutils.fs.ls(CRM_PATH))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/retail_medallion_ws/default/retail_raw/source_crm/cust_info.csv</td><td>cust_info.csv</td><td>855395</td><td>1786079103000</td></tr><tr><td>dbfs:/Volumes/retail_medallion_ws/default/retail_raw/source_crm/prd_info.csv</td><td>prd_info.csv</td><td>26934</td><td>1786079102000</td></tr><tr><td>dbfs:/Volumes/retail_medallion_ws/default/retail_raw/source_crm/sales_details.csv</td><td>sales_details.csv</td><td>3588116</td><td>1786079105000</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls(ERP_PATH))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/retail_medallion_ws/default/retail_raw/source_erp/CUST_AZ12.csv</td><td>CUST_AZ12.csv</td><td>561549</td><td>1786079103000</td></tr><tr><td>dbfs:/Volumes/retail_medallion_ws/default/retail_raw/source_erp/LOC_A101.csv</td><td>LOC_A101.csv</td><td>402669</td><td>1786079103000</td></tr><tr><td>dbfs:/Volumes/retail_medallion_ws/default/retail_raw/source_erp/PX_CAT_G1V2.csv</td><td>PX_CAT_G1V2.csv</td><td>1169</td><td>1786079102000</td></tr></tbody></table></div>
